# %%
import matplotlib.pyplot as plt
from math import pi
from matplotlib.widgets import Button, Slider
G = 6.6743e-11
M = 1.98892*(10**29.99)
GM = G*M
Z = 5.9742*(10**28)
GZ = G*Z
L = 7.36*(10**29)
x = 1.49e11
y = 0
vx = 0
vy = 29765
xl = 3844000000*9 + x
yl = 0
vxl = 0
vyl = vy + 1023*6
t = 100
T = 0
lx = []
ly = []
lxl = []
lyl = []
laxlt = []
laylt = []
laxl = []
layl = []
dist = []
while T < 400*24*60*60:
  ax = -GM*x/((x**2 + y**2)**(3/2))
  ay = -GM*y/((x**2 + y**2)**(3/2))
  vx += ax*t
  vy += ay*t
  x += vx*t
  y += vy*t
  lx.append(x)
  ly.append(y)

  axl = -1*GZ*(xl - x)/(((xl - x)**2 + (yl - y)**2)**(3/2)) + -1*GM*xl/((xl**2 + yl**2)**(3/2)) #- -GM*x/((x**2 + y**2)**(3/2))
  ayl = -1*GZ*(yl - y)/(((xl - x)**2 + (yl - y)**2)**(3/2)) + -1*GM*yl/((xl**2 + yl**2)**(3/2)) #- -GM*y/((x**2 + y**2)**(3/2))
  vxl += axl*t
  vyl += ayl*t
  xl += vxl*t
  yl += vyl*t
  lxl.append(xl)
  lyl.append(yl)
  '''laxl.append(axl)
  layl.append(ayl)
  laxlt.append(T)
  laylt.append(T)
  dist.append(((xl - x)**2 + (yl - y)**2)**0.5)'''

  T += t

plt.plot(lx, ly)
plt.plot(lxl, lyl)
'''plt.plot(lxl, laxlt, '.')
plt.plot(lyl, laylt, '.')'''
# Out:
# "plt.plot(lxl, laxlt, '.')\nplt.plot(lyl, laylt, '.')"

# %%
fig, ax = plt.subplots()
plt.subplots_adjust(left = 0.1, bottom = 0.35)
p, = plt.plot(lxl, lyl, color = "orange")
#plt.axis([-2, 2, -2, 2])

axSlider1 = plt.axes([0.1, 0.2, 0.8, 0.05])
slider1 = Slider(axSlider1, 'Moon mass', valmin = 7.36*(10**15), valmax = 7.36*(10**40), valinit = 7.36*(10**29))

plt.show()

# %%
plt.plot(laxlt, laxl, '.')

# %%
plt.plot(laylt, layl, '.')
